# %% [markdown]
# # Moved
#
# `systematics-flux_asymmetry.ipynb` was merged into the last section of **`systematics-flux.ipynb`**.
#
# Full copy: `archive_syst/systematics-flux_asymmetry.FULL.ipynb`.
